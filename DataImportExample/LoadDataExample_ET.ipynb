# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('BOII_ET_2007to2017.csv', names=['Year','Month','Day','ET'], skiprows=1); # Import csv file, skipping and naming header
df[0:5] # check first 5 records in data frame
# Out:
#    Year  Month  Day     ET
# 0  2007      9    1  4.572
# 1  2007      9    2  4.572
# 2  2007      9    3  4.318
# 3  2007      9    4  3.810
# 4  2007      9    5  1.524

# %%
df['Date'] = pd.to_datetime(df.Year*10000+df.Month*100+df.Day,format='%Y%m%d') # create better date format
df[0:5] # check first 5 records in frame
# Out:
#    Year  Month  Day     ET       Date
# 0  2007      9    1  4.572 2007-09-01
# 1  2007      9    2  4.572 2007-09-02
# 2  2007      9    3  4.318 2007-09-03
# 3  2007      9    4  3.810 2007-09-04
# 4  2007      9    5  1.524 2007-09-05

# %%
df.plot(x='Date', y='ET',figsize=(14,10))
plt.show()

# %%
# I'm leaving your comments for this section Lejo
# They do a good job of explaining what is going on

# Use the pandas .values operator to load the values for solar radiation
# from the pandas dataframe into a numpy array
ET = df['ET'].values # 

# Use numpy array indexing to get solar radiation from October 2, 2000 to September 30, 2017. 
# The 'end' of a numpy array can be indexed using -1: as if the index in the negative direction
# wraps back around to the end of the record
ETt   = ET[1:-1] 

# Similarly get solar radiation from October 1, 2000 to September 29, 2017 by getting data from the 
# beginning of the record to the 'end' minus 1 using the -2 as the index. 
ETtm1 = ET[0:-2]

# Use Matplotlib to create a scatter plot of the two time series, with a title and labeled axes
plt.figure(figsize=(14,10))
plt.plot(ETtm1,ETt,'o')
plt.title('How correlated is today\'s ET with yesterday\'s?')
plt.xlabel('$SR_{t-1}$ mm / day')
plt.ylabel('$SR_t$ mm / day')
plt.show()
